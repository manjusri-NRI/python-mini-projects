# %% [markdown]
# <a href="https://colab.research.google.com/github/manjusri-NRI/python-mini-projects/blob/main/House_size_Vs_House_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
# introduction to ML
# used Libraries - random, numpy,pandas

# %%
#Terms in Machine learning

# 1. Collection: Data used for training, validating and testing the Machine learning model

# 2. Feature (X): Independent variable or input variable - used to predict the target variable

# 3. Target (Y) : Dependent variable - output -we want to predict - Example : predicting Number of bedrooms

# 4. Training Data : Subset of dataset used to train the model

# 5. Testing Data : Subset of dataset used to validate the trained model

# 6. Model : Mathematical representative of relationship between feature and target

# 7. Supervised Learning (SL) : Training the data based on labeled data || model learns from known / labeled data

# 8. Regression : Method to predict continuos values from a model - supervised learning

# 9. Overfitting : When a model learns from training data too well, includes noise - performs poorly new data

# 10. Underfitting : Model is too simpler and does not capture patterns in data

# # Categories in Machine Learning:
# 1. Supervised learning:
#   Model learns from labeled data - i/o pairs
#   Example: Linear registration, Decision trees, Random forest, SVM
#   Best use case so far : House price prediction based on previous/historical data

# 2. Unsupervised learning :
#   Model finds new patterns in unlabeled data without predefined data/lables
#   Example : Clustering (k means), PCA
#   Use case : Customer segmentation in marketing

# 3. Reinforcement learning :
#   Model learns by interacting with environment and receiving the rewards or penalties
#   Example : Deep learning,AlphaGo...
#   Best use case : Self car driving vehicles, Self learning AI boys,SLAM

# %%
# Example : Predicting the House price - Random dataset - generated

# Steps :
# 1. Generate a random dataset
# 2. Train a ML model - linear registration
# 3. Evaluation the Model
# 4. Make prediction

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
#step1:Generate a random dataset
np.random.seed(42)#used to set same sequence of values for the random package
numSamples=100
size=np.random.randint(800,5000,numSamples)
bedrooms =np.random.randint(1,6,numSamples)
washrooms=np.random.randint(1,8,numSamples)
localityScore=np.random.randint(1,10,numSamples)
#Generate house prices with randomness
houseprice = (size* 3000) + (bedrooms *50000) + (washrooms * 30000) + (localityScore * 70000) + np.random.randint(-50000, 50000, numSamples)
#create a DataFrame
df=pd.DataFrame(
{
      'Size':size,
      'Bedrooms':bedrooms,
      'Washrooms':washrooms,
      'LocalityScore':localityScore,
      'Price':houseprice
}
)

# %%
df
# Out:
#     Size  Bedrooms  Washrooms  LocalityScore     Price
# 0   1660         5          2              9   5964758
# 1   4572         4          7              5  14517747
# 2   3892         5          7              8  12708752
# 3   1266         5          6              1   4304573
# 4   4244         3          2              5  13301101
# ..   ...       ...        ...            ...       ...
# 95  1006         1          6              5   3591286
# 96  2284         3          5              1   7240450
# 97  1663         4          6              4   5620352
# 98  3590         1          3              5  11265069
# 99  1363         1          4              5   4573397
#
# [100 rows x 5 columns]

# %%
# Step 2 : Train a ML model - linear regression

# package ( installation) requirements :
# Step 2 : Train a ML model - linear regression

# package ( installation) requirements :
# pip install scikit-learn

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = df[['Size','Bedrooms','Washrooms','LocalityScore']]
y = df['Price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Step 3 : Evaluate the model
# package Requirments :
# sklearn.metrics

from sklearn.metrics import mean_absolute_error,mean_squared_error


y_pred = model.predict(x_test)

MAE = mean_absolute_error(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
RMSE =np.sqrt(MSE)

print(f'Mean Absolute Error : {MAE}')
print(f'Mean Squarred Error : {MSE}')
print(f'Root Mean squarred Error : {RMSE}')
# Out:
# Mean Absolute Error : 25385.345481365337
# Mean Squarred Error : 796791448.4323988
# Root Mean squarred Error : 28227.494547557686

# %%
# Step 4 : Make a prediction
newHouse = np.array([[10000,10,10,10]])
predictedPrice = model.predict(newHouse)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
predictedPrice[0]
# Out:
# 31446796.67668341

# %%
print(f'The predicted price of new house is {predictedPrice[0]}')
# Out:
# The predicted price of new house is 31446796.67668341

# %%
plt.scatter(df['Size'],df['Price'],color = 'blue')
plt.xlabel('Size of the House in sq.ft')
plt.ylabel('Price of the House in crores')
plt.legend()
plt.grid(True)
plt.title('House Size vs House Price')
plt.show()
# Out:
# <ipython-input-85-63fbd98ec089>:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
xSorted = np.sort(x,axis=0)
yPred = model.predict(xSorted)
plt.scatter(df['Size'],df['Price'],color = 'yellow')
plt.plot(xSorted,yPred,color = 'pink',linewidth = 2)
plt.xlabel('Size of the House in sq.ft')
plt.ylabel('Price of the House in crores')
plt.legend()
plt.grid(True)
plt.title('House Size vs House Price')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# <ipython-input-87-6ee866bd46cd>:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
