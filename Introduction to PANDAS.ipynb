# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Credit_Card_Applications.csv')

# %%
dataset
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# 0    100  1213      0
# 1    160     1      0
# 2    280     1      0
# 3      0     1      1
# 4     60   159      1
# ..   ...   ...    ...
# 685    0     1      1
# 686    0    45      0
# 687  100     1      1
# 688  120    12      1
# 689  560     1      1
#
# [690 rows x 16 columns]

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# 0    100  1213      0
# 1    160     1      0
# 2    280     1      0
# 3      0     1      1
# 4     60   159      1
# ..   ...   ...    ...
# 685    0     1      1
# 686    0    45      0
# 687  100     1      1
# 688  120    12      1
# 689  560     1      1
#
# [690 rows x 16 columns]>

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %%
dataset.columns
# Out:
# Index(['CustomerID', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9',
#        'A10', 'A11', 'A12', 'A13', 'A14', 'Class'],
#       dtype='object')

# %%
import random
age = []
height= []
weight = []
speed = []
for _ in range(100):
 age.append(random.randint(0,100))
 height.append(random.randint(0,100))
 weight.append(random.randint(0,100))
 speed.append(random.randint(0,100))

idata = {'Age':age,'Height':height,'Weight':weight,'Speed':speed}

idata
# Out:
# {'Age': [7,
#   29,
#   8,
#   5,
#   78,
#   5,
#   19,
#   33,
#   95,
#   85,
#   28,
#   57,
#   64,
#   40,
#   64,
#   56,
#   50,
#   63,
#   15,
#   55,
#   79,
#   29,
#   47,
#   90,
#   83,
#   86,
#   65,
#   31,
#   84,
#   91,
#   88,
#   77,
#   49,
#   32,
#   11,
#   52,
#   75,
#   53,
#   22,
#   64,
#   39,
#   96,
#   29,
#   93,
#   84,
#   29,
#   73,
#   65,
#   89,
#   19,
#   33,
#   25,
#   94,
#   21,
#   72,
#   91,
#   53,
#   42,
#   15,
#   85,
#   85,
#   98,
#   84,
#   52,
#   51,
#   29,
#   7,
#   24,
#   47,
#   49,
#   11,
#   77,
#   56,
#   19,
#   55,
#   23,
#   84,
#   73,
#   76,
#   26,
#   74,
#   85,
#   19,
#   39,
#   77,
#   51,
#   46,
#   20,
#   85,
#   3,
#   76,
#   41,
#   83,
#   34,
#   48,
#   63,
#   36,
#   83,
#   59,
#   45],
#  'Height': [54,
#   63,
#   32,
#   68,
#   59,
#   79,
#   55,
#   34,
#   69,
#   96,
#   43,
#   57,
#   49,
#   92,
#   71,
#   51,
#   89,
#   77,
#   80,
#   32,
#   86,
#   98,
#   93,
#   94,
#   66,
#   23,
#   43,
#   71,
#   29,
#   8,
#   6,
#   82,
#   9,
#   96,
#   49,
#   52,
#   20,
#   99,
#   39,
#   83,
#   48,
#   24,
#   100,
#   92,
#   19,
#   84,
#   45,
#   34,
#   78,
#   22,
#   4,
#   21,
#   84,
#   45,
#   63,
#   61,
#   4,
#   76,
#   76,
#   45,
#   85,
#   67,
#   50,
#   47,
#   18,
#   75,
#   4,
#   20,
#   92,
#   66,
#   49,
#   16,
#   15,
#   87,
#   96,
#   8,
#   83,
#   95,
#   76,
#   20,
#   66,
#   35,
#   11,
#   17,
#   24,
#   11,
#   72,
#   47,
#   28,
#   31,
#   70,
#   19,
#   46,
#   81,
#   35,
#   8,
#   54,
#   23,
#   61,
#   76],
#  'Weight': [0,
#   6,
#   77,
#   7,
#   22,
#   85,
#   88,
#   83,
#   23,
#   48,
#   37,
#   75,
#   99,
#   9,
#   54,
#   57,
#   53,
#   7,
#   19,
#   58,
#   28,
#   76,
#   100,
#   70,
#   92,
#   53,
#   87,
#   23,
#   24,
#   80,
#   51,
#   78,
#   99,
#   24,
#   1,
#   88,
#   83,
#   66,
#   84,
#   97,
#   87,
#   80,
#   29,
#   77,
#   95,
#   46,
#   14,
#   8,
#   79,
#   32,
#   77,
#   48,
#   6,
#   99,
#   88,
#   14,
#   15,
#   5,
#   16,
#   32,
#   6,
#   49,
#   88,
#   94,
#   12,
#   69,
#   77,
#   41,
#   37,
#   75,
#   57,
#   39,
#   55,
#   34,
#   30,
#   30,
#   55,
#   97,
#   61,
#   60,
#   24,
#   50,
#   98,
#   82,
#   52,
#   60,
#   61,
#   54,
#   45,
#   7,
#   12,
#   20,
#   14,
#   87,
#   25,
#   75,
#   79,
#   95,
#   30,
#   93],
#  'Speed': [80,
#   35,
#   93,
#   47,
#   28,
#   33,
#   46,
#   18,
#   40,
#   11,
#   95,
#   67,
#   72,
#   44,
#   24,
#   82,
#   56,
#   41,
#   80,
#   86,
#   88,
#   42,
#   18,
#   21,
#   95,
#   25,
#   24,
#   52,
#   90,
#   42,
#   22,
#   26,
#   84,
#   35,
#   32,
#   46,
#   37,
#   77,
#   20,
#   99,
#   98,
#   26,
#   36,
#   80,
#   84,
#   68,
#   86,
#   75,
#   63,
#   4,
#   21,
#   3,
#   22,
#   79,
#   27,
#   0,
#   14,
#   4,
#   35,
#   21,
#   82,
#   24,
#   22,
#   75,
#   14,
#   22,
#   15,
#   20,
#   34,
#   1,
#   96,
#   51,
#   43,
#   63,
#   42,
#   73,
#   1,
#   31,
#   74,
#   20,
#   72,
#   46,
#   44,
#   74,
#   90,
#   22,
#   51,
#   42,
#   25,
#   7,
#   32,
#   12,
#   91,
#   61,
#   72,
#   24,
#   21,
#   99,
#   98,
#   33]}

# %%
df1 = pd.DataFrame(idata)

# %%
df1.describe()
# Out:
#               Age      Height      Weight       Speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    53.040000   53.050000   52.870000   47.180000
# std     27.201426   28.701661   30.712632   29.076138
# min      3.000000    4.000000    0.000000    0.000000
# 25%     29.000000   27.000000   24.000000   22.000000
# 50%     52.500000   53.000000   54.000000   42.000000
# 75%     77.250000   77.250000   80.000000   74.250000
# max     98.000000  100.000000  100.000000   99.000000

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0     7      54
# 1    29      63
# 2     8      32
# 3     5      68
# 4    78      59
# ..  ...     ...
# 95   63       8
# 96   36      54
# 97   83      23
# 98   59      61
# 99   45      76
#
# [100 rows x 2 columns]

# %%
df1[0::2]
# Out:
#     Age  Height  Weight  Speed
# 0     7      54       0     80
# 2     8      32      77     93
# 4    78      59      22     28
# 6    19      55      88     46
# 8    95      69      23     40
# 10   28      43      37     95
# 12   64      49      99     72
# 14   64      71      54     24
# 16   50      89      53     56
# 18   15      80      19     80
# 20   79      86      28     88
# 22   47      93     100     18
# 24   83      66      92     95
# 26   65      43      87     24
# 28   84      29      24     90
# 30   88       6      51     22
# 32   49       9      99     84
# 34   11      49       1     32
# 36   75      20      83     37
# 38   22      39      84     20
# 40   39      48      87     98
# 42   29     100      29     36
# 44   84      19      95     84
# 46   73      45      14     86
# 48   89      78      79     63
# 50   33       4      77     21
# 52   94      84       6     22
# 54   72      63      88     27
# 56   53       4      15     14
# 58   15      76      16     35
# 60   85      85       6     82
# 62   84      50      88     22
# 64   51      18      12     14
# 66    7       4      77     15
# 68   47      92      37     34
# 70   11      49      57     96
# 72   56      15      55     43
# 74   55      96      30     42
# 76   84      83      55      1
# 78   76      76      61     74
# 80   74      66      24     72
# 82   19      11      98     44
# 84   77      24      52     90
# 86   46      72      61     51
# 88   85      28      45     25
# 90   76      70      12     32
# 92   83      46      14     91
# 94   48      35      25     72
# 96   36      54      79     21
# 98   59      61      30     98

# %%
#Filter
filter1 = df1['Weight']>50

# %%
df1.loc[[0,3],['Age','Height']]
# Out:
#    Age  Height
# 0    7      54
# 3    5      68

# %%
df1.sort_index()
# Out:
#     Age  Height  Weight  Speed
# 0     7      54       0     80
# 1    29      63       6     35
# 2     8      32      77     93
# 3     5      68       7     47
# 4    78      59      22     28
# ..  ...     ...     ...    ...
# 95   63       8      75     24
# 96   36      54      79     21
# 97   83      23      95     99
# 98   59      61      30     98
# 99   45      76      93     33
#
# [100 rows x 4 columns]

# %%
df1[0::2].describe()
# Out:
#            Age      Height      Weight      Speed
# count  50.0000   50.000000   50.000000  50.000000
# mean   55.4200   51.940000   50.900000  52.580000
# std    27.3407   27.849017   31.970171  30.036094
# min     7.0000    4.000000    0.000000   1.000000
# 25%    33.7500   29.750000   23.250000  24.250000
# 50%    57.5000   52.000000   52.500000  43.500000
# 75%    78.7500   75.000000   82.000000  83.500000
# max    95.0000  100.000000  100.000000  98.000000

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 2     8      32      77     93
# 5     5      79      85     33
# 6    19      55      88     46
# 7    33      34      83     18
# 11   57      57      75     67
# 12   64      49      99     72
# 14   64      71      54     24
# 15   56      51      57     82
# 16   50      89      53     56
# 19   55      32      58     86
# 21   29      98      76     42
# 22   47      93     100     18
# 23   90      94      70     21
# 24   83      66      92     95
# 25   86      23      53     25
# 26   65      43      87     24
# 29   91       8      80     42
# 30   88       6      51     22
# 31   77      82      78     26
# 32   49       9      99     84
# 35   52      52      88     46
# 36   75      20      83     37
# 37   53      99      66     77
# 38   22      39      84     20
# 39   64      83      97     99
# 40   39      48      87     98
# 41   96      24      80     26
# 43   93      92      77     80
# 44   84      19      95     84
# 48   89      78      79     63
# 50   33       4      77     21
# 53   21      45      99     79
# 54   72      63      88     27
# 62   84      50      88     22
# 63   52      47      94     75
# 65   29      75      69     22
# 66    7       4      77     15
# 69   49      66      75      1
# 70   11      49      57     96
# 72   56      15      55     43
# 76   84      83      55      1
# 77   73      95      97     31
# 78   76      76      61     74
# 79   26      20      60     20
# 82   19      11      98     44
# 83   39      17      82     74
# 84   77      24      52     90
# 85   51      11      60     22
# 86   46      72      61     51
# 87   20      47      54     42
# 93   34      81      87     61
# 95   63       8      75     24
# 96   36      54      79     21
# 97   83      23      95     99
# 99   45      76      93     33

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 2     8      32      77     93
# 5     5      79      85     33
# 6    19      55      88     46
# 7    33      34      83     18
# 11   57      57      75     67
# 12   64      49      99     72
# 14   64      71      54     24
# 15   56      51      57     82
# 16   50      89      53     56
# 19   55      32      58     86
# 21   29      98      76     42
# 22   47      93     100     18
# 23   90      94      70     21
# 24   83      66      92     95
# 25   86      23      53     25
# 26   65      43      87     24
# 29   91       8      80     42
# 30   88       6      51     22
# 31   77      82      78     26
# 32   49       9      99     84
# 35   52      52      88     46
# 36   75      20      83     37
# 37   53      99      66     77
# 38   22      39      84     20
# 39   64      83      97     99
# 40   39      48      87     98
# 41   96      24      80     26
# 43   93      92      77     80
# 44   84      19      95     84
# 48   89      78      79     63
# 50   33       4      77     21
# 53   21      45      99     79
# 54   72      63      88     27
# 62   84      50      88     22
# 63   52      47      94     75
# 65   29      75      69     22
# 66    7       4      77     15
# 69   49      66      75      1
# 70   11      49      57     96
# 72   56      15      55     43
# 76   84      83      55      1
# 77   73      95      97     31
# 78   76      76      61     74
# 79   26      20      60     20
# 82   19      11      98     44
# 83   39      17      82     74
# 84   77      24      52     90
# 85   51      11      60     22
# 86   46      72      61     51
# 87   20      47      54     42
# 93   34      81      87     61
# 95   63       8      75     24
# 96   36      54      79     21
# 97   83      23      95     99
# 99   45      76      93     33

# %%
filter2 = df1['Age']>50

# %%
df1.loc[filter1 & filter2]
# Out:
#     Age  Height  Weight  Speed
# 11   57      57      75     67
# 12   64      49      99     72
# 14   64      71      54     24
# 15   56      51      57     82
# 19   55      32      58     86
# 23   90      94      70     21
# 24   83      66      92     95
# 25   86      23      53     25
# 26   65      43      87     24
# 29   91       8      80     42
# 30   88       6      51     22
# 31   77      82      78     26
# 35   52      52      88     46
# 36   75      20      83     37
# 37   53      99      66     77
# 39   64      83      97     99
# 41   96      24      80     26
# 43   93      92      77     80
# 44   84      19      95     84
# 48   89      78      79     63
# 54   72      63      88     27
# 62   84      50      88     22
# 63   52      47      94     75
# 72   56      15      55     43
# 76   84      83      55      1
# 77   73      95      97     31
# 78   76      76      61     74
# 84   77      24      52     90
# 85   51      11      60     22
# 95   63       8      75     24
# 97   83      23      95     99
