# %% [markdown]
# <a href="https://colab.research.google.com/github/manjusri-NRI/python-mini-projects/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1 = []
a2 = []
a3 = []
a4 = []
a5 = []

# %%
for _ in range(1000) :
   a1.append(random.randint(0,100))
   a2.append(random.randint(50,70))
   a3.append(random.randint(10,20))
   a4.append(random.randint(5,10))
   a5.append(random.randint(20,80))

# %%
df = {
    'grade' : a1,
    'weigth' : a2,
    'friends' : a3,
    'cousins' : a4,
    'projects' : a5
}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weigth  friends  cousins  projects
# 0        3      66       14        6        72
# 1       81      61       15        5        80
# 2       94      70       14        6        55
# 3       24      58       19        8        32
# 4       51      61       10        8        27
# ..     ...     ...      ...      ...       ...
# 995     59      68       16        9        21
# 996     73      56       14        7        45
# 997     81      64       16        5        62
# 998     18      51       12        6        24
# 999     90      63       13        5        30
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weigth      friends      cousins     projects
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     51.118000    60.140000    15.069000     7.395000    50.194000
# std      29.289485     6.073491     3.121215     1.657626    17.184984
# min       0.000000    50.000000    10.000000     5.000000    20.000000
# 25%      27.000000    55.000000    12.000000     6.000000    35.750000
# 50%      52.000000    60.000000    15.000000     7.000000    50.000000
# 75%      76.000000    65.000000    18.000000     9.000000    65.000000
# max     100.000000    70.000000    20.000000    10.000000    80.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
friend15 = df1['friends'] > 15

# %%
df1[friend15]
# Out:
#      grade  weigth  friends  cousins  projects
# 3       24      58       19        8        32
# 5        1      56       19        9        42
# 6       90      66       18        9        36
# 7       23      59       16        8        75
# 9       51      62       20        9        75
# ..     ...     ...      ...      ...       ...
# 989     59      62       19       10        61
# 990     26      56       16       10        21
# 994     32      64       17        8        29
# 995     59      68       16        9        21
# 997     81      64       16        5        62
#
# [466 rows x 5 columns]

# %%
grade50 = df1['grade'] > 50

# %%
df1[grade50]
# Out:
#      grade  weigth  friends  cousins  projects
# 1       81      61       15        5        80
# 2       94      70       14        6        55
# 4       51      61       10        8        27
# 6       90      66       18        9        36
# 8       56      58       14        6        67
# ..     ...     ...      ...      ...       ...
# 991     59      65       12        9        56
# 995     59      68       16        9        21
# 996     73      56       14        7        45
# 997     81      64       16        5        62
# 999     90      63       13        5        30
#
# [512 rows x 5 columns]

# %%
df1[friend15 & grade50].describe()
# Out:
#             grade      weigth     friends     cousins    projects
# count  242.000000  242.000000  242.000000  242.000000  242.000000
# mean    75.822314   59.909091   17.900826    7.429752   49.615702
# std     14.528175    6.026911    1.454168    1.643932   17.601308
# min     51.000000   50.000000   16.000000    5.000000   20.000000
# 25%     63.000000   55.000000   17.000000    6.000000   35.000000
# 50%     75.000000   60.000000   18.000000    7.000000   48.000000
# 75%     88.000000   65.000000   19.000000    9.000000   64.750000
# max    100.000000   70.000000   20.000000   10.000000   80.000000

# %%
,df1[friend15 & grade50]['friends']
# Out:
# 6      18
# 9      20
# 11     19
# 13     17
# 17     16
#        ..
# 974    18
# 985    18
# 989    19
# 995    16
# 997    16
# Name: friends, Length: 242, dtype: int64

# %%
# %matplotlib inline

# %%
df1[friend15 & grade50].plot()
# Out:
# <Axes: >

# %%
df1[friend15 & grade50].plot(x= 'grade',y= 'projects', kind= 'bar')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade50].plot(x= 'grade' ,y= 'projects', kind= 'scatter',title='Sample graph')
plt.xlabel('x Axis')
plt.ylabel('y Axis')
plt.legend('Test Data')
plt.show()

# %%
from matplotlib import pyplot as lib

# %%
fdf = df1[friend15 & grade50]

# %%
fdf
# Out:
#      grade  weigth  friends  cousins  projects
# 6       90      66       18        9        36
# 9       51      62       20        9        75
# 11      79      50       19        8        46
# 13      87      56       17        6        69
# 17      73      66       16       10        47
# ..     ...     ...      ...      ...       ...
# 974     55      51       18        9        66
# 985     70      51       18        5        24
# 989     59      62       19       10        61
# 995     59      68       16        9        21
# 997     81      64       16        5        62
#
# [242 rows x 5 columns]

# %%
df1
# Out:
#      grade  weigth  friends  cousins  projects
# 0        3      66       14        6        72
# 1       81      61       15        5        80
# 2       94      70       14        6        55
# 3       24      58       19        8        32
# 4       51      61       10        8        27
# ..     ...     ...      ...      ...       ...
# 995     59      68       16        9        21
# 996     73      56       14        7        45
# 997     81      64       16        5        62
# 998     18      51       12        6        24
# 999     90      63       13        5        30
#
# [1000 rows x 5 columns]
