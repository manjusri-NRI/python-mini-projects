# %%
def easy_quiz():
    score = 0
    
    # Question 1
    print("Question 1: What is 5 - 3?")
    answer1 = input("a) 2 b) 4 c) 5 d) 6 Your answer: ")

    if answer1 == "a":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is 2.")
    
    # Question 2
    print("Question 2: What is 10 - 2?")
    answer2 = input("a) 10 b) 9  c) 8 d) 13 Your answer: ")
    
    if answer2 == "c":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is 8.")

        # Question 3
    print("Question 3: What is 20-1?")
    answer3 = input("a) 6 b) 7 c) 19 d) 9 Your answer: ")
    
    if answer3 == "c":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is 19.")

        # Question 4
    print("Question 4: What is 50 - 18?")
    answer4 = input("a) 32 b) 17 c) 15 d) 9 Your answer: ")
    
    if answer4 == "a":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is 32.")

        # Question 5
    print("Question 5: What is 40 - 20?")
    answer5 = input("a) 14 b) 7 c) 20 d) 19 Your answer: ")
    
    if answer5 == "c":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is 20.")

        # Question 6
    print("Question 6: What is 24 - 22?")
    answer6 = input("a) 5 b) 2 c) 4 d) 6 Your answer: ")
    
    if answer6 == "b":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is 2.")

        # Question 7
    print("Question 7: What is 80 - 10?")
    answer7 = input("a) 23 b) 27 c) 38 d) 70 Your answer: ")
    
    if answer7 == "d":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is 70.")
    
    # Question 8
    print("Question 8: What is 50 - 30?")
    answer8 = input("a) 60 b) 70 c) 20 d) 90 Your answer: ")
    
    if answer8 == "c":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is 20.")

        # Question 9
    print("Question 9: What is 156 - 40?")
    answer9 = input("a) 116 b) 197 c) 80 d) 90 Your answer: ")
    
    if answer9 == "a":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is 116.")

        # Question 10
    print("Question 10: What is 46 - 16?")
    answer10 = input("a) 60 b) 30 c) 74 d) 76 Your answer: ")
    
    if answer10 == "b":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is 30.")
    
    
    # Final score
    print(f"Your final score is: {score}/100")

# Run the quiz
easy_quiz()
# Out:
# Question 1: What is 5 - 3?
# Correct
# Question 2: What is 10 - 2?
# Correct
# Question 3: What is 20-1?
# Correct
# Question 4: What is 50 - 18?
# Correct
# Question 5: What is 40 - 20?
# Correct
# Question 6: What is 24 - 22?
# Correct
# Question 7: What is 80 - 10?
# Correct
# Question 8: What is 50 - 30?
# Correct
# Question 9: What is 156 - 40?
# Correct
# Question 10: What is 46 - 16?
# Correct
# Your final score is: 100/100
